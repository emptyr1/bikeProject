# %% [markdown]
# ## Hello

# %%
import psycopg2

try:
    conn_string = "host='localhost' dbname='bikesproject' user='postgres' password='p'"
    print "Connecting to database\n	->%s" % (conn_string)
    conn = psycopg2.connect(conn_string)
    cursor = conn.cursor()
    print "Connected!\n"
except:
    print "I am unable to connect to the database"
# Out:
# Connecting to database
# 	->host='localhost' dbname='bikesproject' user='postgres' password='p'
# Connected!

# %%
#work_mem = 2048
import pandas as pd
import psycopg2
#engine = sq.create_engine("postgresql+psycopg2://username:password@host:port/database")
name_of_table = 'ny_stations'
conn = psycopg2.connect("dbname=bikesproject user=postgres")
cur = conn.cursor()
#cur.execute("SELECT * FROM ny_each_trip LIMIT 100;")
#cur.fetchall()
trips_station = pd.read_sql_query('select * from "trips_and_stations" limit 100; ',con=conn)
trips_station.head()
#df.ix[:,['latitude', 'longitude']]
# Out:
#      id  trip_duration          start_time           stop_time  \
# 0   289         1148.0 2014-01-01 01:43:12 2014-01-01 02:02:20
# 1  1052         1636.0 2014-01-01 09:56:27 2014-01-01 10:23:43
# 2  1311          681.0 2014-01-01 11:13:40 2014-01-01 11:25:01
# 3  2472          854.0 2014-01-01 14:01:36 2014-01-01 14:15:50
# 4  2477          652.0 2014-01-01 14:02:01 2014-01-01 14:12:53
#
#    start_station_id  end_station_id  bike_id   user_type  birth_year  gender  \
# 0               453             137    15411  Subscriber      1968.0       1
# 1               417             137    21309  Subscriber      1980.0       1
# 2               492             137    19304  Subscriber      1985.0       1
# 3              2003             137    18236  Subscriber      1967.0       1
# 4               305             137    16208  Subscriber      1987.0       2
#
#            ...           start_boroname  start_ntacode  \
# 0          ...                Manhattan           MN13
# ...

# %%
origin = trips_station['start_station_latitude'].map(str) +',' + trips_station['start_station_longitude'].map(str)
destination = trips_station['end_station_latitude'].map(str) +',' + trips_station['end_station_longitude'].map(str)
#type(origin[0])
origin.to_string()
# Out:
# u'0        40.74475148,-73.99915362\n1        40.71291224,-74.01020234\n2        40.75019995,-73.99093085\n3     40.733812192,-73.9805442095\n4        40.76095756,-73.96724467\n5            40.734232,-73.986923\n6            40.734232,-73.986923\n7        40.75934501,-73.96759673\n8        40.75934501,-73.96759673\n9         40.76370739,-73.9851615\n10        40.7575699,-73.99098507\n11       40.75019995,-73.99093085\n12        40.7575699,-73.99098507\n13    40.752062307,-73.9816324043\n14       40.75097711,-73.98765428\n15       40.71754834,-74.01322069\n16       40.75044999,-73.99481051\n17        40.7643971,-73.97371465\n18        40.7575699,-73.99098507\n19       40.74854862,-73.98808416\n20       40.75527307,-73.98316936\n21       40.76340613,-73.97722479\n22       40.73624527,-73.98473765\n23       40.75968085,-73.97031366\n24       40.73912601,-73.97973776\n25        40.76370739,-73.9851615\n26       40.76344058,-73.98268129\n27       40.76669671,-73.99061728\n28       40.7609
# ...

# %%
conn.commit()
cur.close()
conn.close()

# %%
import googlemaps
from datetime import datetime
gmaps = googlemaps.Client(key='AIzaSyDEJBc0HYUpqO9SFDCtZPcyjZLSXkVlXRM')

# %%
## call to API
def get_directions(origin, destination):
    #Get directions for public transit for getting bike directions from start station to \
    #end station as origin and destination from postgres
    direction_results = gmaps.directions(origin=origin,
                                     destination=destination,
                                     mode="bicycling"
                                     )

    return direction_results

    # Look up an address with reverse geocoding
    #reverse_geocode_result = gmaps.reverse_geocode((40.714224, -73.961452))
get_directions(origin[0], destination[0])
# Out:
# [{u'bounds': {u'northeast': {u'lat': 40.7660501, u'lng': -73.97289049999999},
#    u'southwest': {u'lat': 40.7446311, u'lng': -73.99917909999999}},
#   u'copyrights': u'Map data \xa92016 Google',
#   u'legs': [{u'distance': {u'text': u'2.3 mi', u'value': 3751},
#     u'duration': {u'text': u'14 mins', u'value': 824},
#     u'end_address': u'50 E 56th St, New York, NY 10022, USA',
#     u'end_location': {u'lat': 40.7616402, u'lng': -73.97289049999999},
#     u'start_address': u'301 W 22nd St, New York, NY 10011, USA',
#     u'start_location': {u'lat': 40.744717, u'lng': -73.99917909999999},
#     u'steps': [{u'distance': {u'text': u'66 ft', u'value': 20},
#       u'duration': {u'text': u'1 min', u'value': 4},
#       u'end_location': {u'lat': 40.7446311, u'lng': -73.9989763},
#       u'html_instructions': u'Head <b>southeast</b> on <b>W 22nd St</b> toward <b>8th Ave</b>',
#       u'polyline': {u'points': u'o}twFz}sbMPg@'},
# ...

# %%
#DON'T RUN THIS REPEATEDLY. API HAS RESTRICTIONS of 2500 CALLS/DAY!!
all_legs = []
full_trip = []
for i in range(len(origin)):
    api_output = get_directions(origin[i], destination[i])
    estimated_distance = api_output[0]['legs'][0]['distance']['value']
    estimated_duration = api_output[0]['legs'][0]['duration']['value']
    full_trip.extend((estimated_distance, estimated_duration))
    steps = api_output[0]['legs'][0]['steps']
    routes = []
    for i in range(len(steps)):
        points = steps[i]['polyline']['points']
        routes.extend(decode_poly(points))
    full_trip.append(routes)
    
#print out_legs

# %%
full_trip

# %%
df = pd.DataFrame(estimated_distance)

#df.to_csv('../data/100rides.csv')
df
# Out:
#        0
# 0   3751
# 1   8017
# 2   3149
# 3   3971
# 4   1246
# 5   5849
# 6   5849
# 7   1015
# 8   1015
# 9   1311
# 10  2236
# 11  3149
# 12  2236
# 13  1413
# 14  3215
# 15  7370
# 16  2995
# 17   447
# 18  2236
# 19  3752
# 20  1538
# 21   414
# 22  3437
# 23   372
# 24  3173
# 25  1311
# 26  1232
# 27  1820
# 28  1246
# 29  5285
# ..   ...
# 70   697
# 71  3149
# 72  2241
# 73   913
# 74   913
# 75  1387
# 76  1517
# 77  1836
# 78  1820
# 79  1015
# 80  3149
# 81  2236
# 82  1181
# 83  2852
# 84  3149
# 85  1107
# 86  1037
# 87  2006
# 88   779
# 89  1133
# 90  1133
# 91  3752
# 92  1772
# 93  1908
# 94   913
# 95  3149
# 96  2241
# 97   414
# 98  1107
# 99  2241
#
# [100 rows x 1 columns]

# %%
#print len(directions_result[0])
routes = []
for i in range(len(steps)):
    points = steps[i]['polyline']['points']
    #print decode_poly(points)
    routes.extend(decode_poly(points))
print routes
directions_result[0]['legs'][0]['steps'][0]['polyline']
# Out:
# [(-73.96543, 40.63153), (-73.96506, 40.62963), (-73.96506, 40.62963), (-73.96415, 40.62973), (-73.96415, 40.62973), (-73.9646, 40.63212), (-73.96462, 40.63219), (-73.96478, 40.63323), (-73.96478, 40.63335), (-73.96479, 40.63342), (-73.96481, 40.6336), (-73.96487, 40.63391), (-73.96504, 40.6347), (-73.96538, 40.63628), (-73.96579, 40.63845), (-73.96617, 40.64044), (-73.96689, 40.6441), (-73.96731, 40.64644), (-73.96732, 40.64655), (-73.96756, 40.64769), (-73.96788, 40.64943), (-73.96788, 40.64946), (-73.96789, 40.64949), (-73.9679, 40.64954), (-73.96791, 40.64957), (-73.96793, 40.6496), (-73.96793, 40.6496), (-73.96882, 40.64925), (-73.96971, 40.6489), (-73.97008, 40.64875), (-73.97008, 40.64875), (-73.97079, 40.64984), (-73.9714, 40.65078), (-73.97144, 40.65081), (-73.9715, 40.65084), (-73.9715, 40.65084), (-73.97147, 40.6509), (-73.97146, 40.65096), (-73.97146, 40.65101), (-73.97145, 40.65106), (-73.97146, 40.6511), (-73.97146, 40.65115), (-73.97148, 40.65119), (-73.9715, 40.65124),
# ...

# %%
df = pd.DataFrame(routes2)
df['rtime'] = pd.Series(np.arange(0,len(df)))
df.columns = ['longitude', 'latitude', 'route']
df.to_csv('test2.csv')

# %%
ElevationKey = 'AIzaSyCZo5sLK2ER5OLKxc9Y2-iS6kEV7BRfQ0o'

# %%
def decode_poly(point_str):
    '''Decodes a polyline that has been encoded using Google's algorithm
    http://code.google.com/apis/maps/documentation/polylinealgorithm.html
    
    This is a generic method that returns a list of (latitude, longitude) 
    tuples.
    
    :param point_str: Encoded polyline string.
    :type point_str: string
    :returns: List of 2-tuples where each tuple is (latitude, longitude)
    :rtype: list
    
    '''
            
    # sone coordinate offset is represented by 4 to 5 binary chunks
    coord_chunks = [[]]
    for char in point_str:
        
        # convert each character to decimal from ascii
        value = ord(char) - 63     
        # values that have a chunk following have an extra 1 on the left
        split_after = not (value & 0x20)         
        value &= 0x1F
        
        coord_chunks[-1].append(value)
        
        if split_after:
                coord_chunks.append([])
        
    del coord_chunks[-1]
    
    coords = []
    
    for coord_chunk in coord_chunks:
        coord = 0
        
        for i, chunk in enumerate(coord_chunk):                    
            coord |= chunk << (i * 5) 
        
        #there is a 1 on the right if the coord is negative
        if coord & 0x1:
            coord = ~coord #invert
        coord >>= 1
        coord /= 100000.0
                    
        coords.append(coord)
    
    # convert the 1 dimensional list to a 2 dimensional list and offsets to 
    # actual values
    points = []
    prev_x = 0
    prev_y = 0
    for i in xrange(0, len(coords) - 1, 2):
        if coords[i] == 0 and coords[i + 1] == 0:
            continue
        
        prev_x += coords[i + 1]
        prev_y += coords[i]
        # a round to 6 digits ensures that the floats are the same as when 
        # they were encoded
        points.append((round(prev_x, 6), round(prev_y, 6)))
    
    return points

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(q)

# %%
df['route'] = pd.Series(np.arange(1,len(df)))
df.columns = ['lat', 'long', 'route']

# %%
df.head()
# Out:
#         lat      long  route
# 0 -73.96415  40.62973    1.0
# 1 -73.96460  40.63212    2.0
# 2 -73.96462  40.63219    3.0
# 3 -73.96478  40.63323    4.0
# 4 -73.96478  40.63335    5.0

# %%
emissions = pd.read_excel('../data/Jones-Kammen-2013-ZipCodeResults.xlsx', 1)

# %%
emissions.head()
# Out:
#    ZipCode  Population  HouseholdsPerZipCode  PersonsPerHousehold  \
# 0     1001       16576                  7279                 2.27
# 1     1002       36794                 10177                 2.46
# 2     1005        5077                  1979                 2.69
# 3     1007       13017                  5065                 2.65
# 4     1008        1235                   525                 2.68
#
#    AverageHouseValue  IncomePerHousehold   Latitude  Longitude  Elevation  \
# 0             127300               45735  42.070743 -72.625036         70
# 1             178200               42567  42.376860 -72.469140        140
# 2             123800               50395  42.433445 -72.114991        475
# 3             145100               52425  42.278884 -72.410245        140
# 4             128100               52663  42.143237 -72.930317         70
#
#   State        ...        Nat. Gas (cu.ft.) FUELOIL (gallons)  \
# ...

# %%
nysf_emissions = emissions[emissions['StateFullName'].isin(['New York', 'California'])]

# %%
nysf_emissions.to_csv('../nysf_emissions.csv')

# %%
import pyspark

# %%
sc = pyspark.SparkContext()
